# %%
# !pip install kaggle

# %%
# configuring the path of Kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# daatset api
# !kaggle competitions download -c cifar-10
# Out:
# cifar-10.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls
# Out:
# cifar-10.zip  sample_data	    test.7z  train.7z
# kaggle.json   sampleSubmission.csv  train    trainLabels.csv

# %%
# extracting the compessed Dataset
from zipfile import ZipFile
dataset = '/content/cifar-10.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
# !ls
# Out:
# cifar-10.zip  sample_data	    test.7z  train.7z
# kaggle.json   sampleSubmission.csv  train    trainLabels.csv

# %%
# !pip install py7zr

# %%
import py7zr

archive = py7zr.SevenZipFile('/content/train.7z', mode='r')
archive.extractall()     #archive.extractall(path='/content/Training Data')
archive.close()

# %%
# !ls
# Out:
# cifar-10.zip  sample_data	    test.7z  train.7z
# kaggle.json   sampleSubmission.csv  train    trainLabels.csv

# %% [markdown]
# Importing the Dependencies

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split

# %%
filenames = os.listdir('/content/train')

# %%
type(filenames)
# Out:
# list

# %%
len(filenames)
# Out:
# 50000

# %%
print(filenames[0:5])
print(filenames[-5:])
# Out:
# ['4398.png', '44721.png', '34896.png', '6865.png', '14144.png']
# ['39734.png', '40307.png', '48399.png', '27610.png', '10132.png']

# %% [markdown]
# Lables processing

# %%
labels_df = pd.read_csv("/content/trainLabels.csv")

# %%
labels_df.head()
# Out:
#    id       label
# 0   1        frog
# 1   2       truck
# 2   3       truck
# 3   4        deer
# 4   5  automobile

# %%
labels_df[labels_df["id"] == 7796]
# Out:
#         id label
# 7795  7796  frog

# %%
labels_df.head()
# Out:
#    id       label
# 0   1        frog
# 1   2       truck
# 2   3       truck
# 3   4        deer
# 4   5  automobile

# %%
labels_df.tail()
# Out:
#           id       label
# 49995  49996        bird
# 49996  49997        frog
# 49997  49998       truck
# 49998  49999  automobile
# 49999  50000  automobile

# %%
labels_df['label'].value_counts()
# Out:
# label
# frog          5000
# truck         5000
# deer          5000
# automobile    5000
# bird          5000
# horse         5000
# ship          5000
# cat           5000
# dog           5000
# airplane      5000
# Name: count, dtype: int64

# %%
#labelss = labels_df['label'].replace({'airplane':0,'automobile':1, 'bird':2, 'cat':3,  'deer':4, 'dog':5, 'frog':6, 'horse':7, 'ship':8, 'truck':9})

# %%
#print(labelss[0:5])
#print(labelss[-5:])

# %%
#type(labelss)

# %%
#lablesss = list(labelss)

# %%
#type(lablesss)

# %%
labels_df['label'].unique()
# Out:
# array(['frog', 'truck', 'deer', 'automobile', 'bird', 'horse', 'ship',
#        'cat', 'dog', 'airplane'], dtype=object)

# %%
labels_dictionary = {'airplane':0,'automobile':1, 'bird':2, 'cat':3,  'deer':4, 'dog':5, 'frog':6, 'horse':7, 'ship':8, 'truck':9}

labels = [labels_dictionary[i] for i in labels_df['label'] ]

# %%
print(labels[0:5])
print(labels[-5:])
# Out:
# [6, 9, 9, 4, 1]
# [2, 6, 9, 1, 1]

# %%
# displaying sample image
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/train/7796.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=32x32>

# %%
# displaying sample image
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/train/45888.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=32x32>

# %%
labels_df[labels_df['id'] == 45888]
# Out:
#           id label
# 45887  45888   dog

# %%
labels_df.head()
# Out:
#    id       label
# 0   1        frog
# 1   2       truck
# 2   3       truck
# 3   4        deer
# 4   5  automobile

# %%
id_list = list(labels_df['id'])

# %%
print(id_list[0:5])
print(id_list[-5:])
# Out:
# [1, 2, 3, 4, 5]
# [49996, 49997, 49998, 49999, 50000]

# %% [markdown]
# **Image processing**

# %%
# converting images to numpy arrayes

train_data = '/content/train/'

data = []

for id in id_list:
  img_path = train_data + str(id) + '.png'
  img = Image.open(img_path)
  img = np.array(img)
  data.append(img)

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 50000

# %%
type(data[0])
# Out:
# numpy.ndarray

# %%
data[0].shape
# Out:
# (32, 32, 3)

# %%
data[0]
# Out:
# array([[[ 59,  62,  63],
#         [ 43,  46,  45],
#         [ 50,  48,  43],
#         ...,
#         [158, 132, 108],
#         [152, 125, 102],
#         [148, 124, 103]],
#
#        [[ 16,  20,  20],
#         [  0,   0,   0],
#         [ 18,   8,   0],
#         ...,
#         [123,  88,  55],
#         [119,  83,  50],
#         [122,  87,  57]],
#
#        [[ 25,  24,  21],
#         [ 16,   7,   0],
#         [ 49,  27,   8],
#         ...,
#         [118,  84,  50],
#         [120,  84,  50],
#         [109,  73,  42]],
#
#        ...,
#
#        [[208, 170,  96],
#         [201, 153,  34],
#         [198, 161,  26],
#         ...,
#         [160, 133,  70],
#         [ 56,  31,   7],
#         [ 53,  34,  20]],
#
#        [[180, 139,  96],
#         [173, 123,  42],
#         [186, 144,  30],
#         ...,
#         [184, 148,  94],
#         [ 97,  62,  34],
#         [ 83,  53,  34]],
#
#        [[177, 144, 116],
#         [168, 129,  94],
#         [179, 142,  87],
# ...

# %%
# convert images list to numpy arrays

X = np.array(data)
Y = np.asarray(labels)

# %%
type(X)
# Out:
# numpy.ndarray

# %%
print(X.shape)
print(Y.shape)
# Out:
# (50000, 32, 32, 3)
# (50000,)

# %% [markdown]
# **Train Test Split**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (40000,)
# (10000,)

# %%
# scaling the data

X_train_scaled = X_train/255
X_test_scaled = X_test/255

# %%
X_train_scaled[0]
# Out:
# array([[[0.81960784, 0.82352941, 0.79607843],
#         [0.83529412, 0.83921569, 0.81960784],
#         [0.85490196, 0.85882353, 0.84313725],
#         ...,
#         [0.49803922, 0.29019608, 0.15294118],
#         [0.47843137, 0.26666667, 0.1372549 ],
#         [0.45490196, 0.24705882, 0.1254902 ]],
#
#        [[0.82352941, 0.82352941, 0.79215686],
#         [0.83529412, 0.83921569, 0.81176471],
#         [0.85490196, 0.8627451 , 0.83921569],
#         ...,
#         [0.48627451, 0.2745098 , 0.1372549 ],
#         [0.4745098 , 0.2627451 , 0.12941176],
#         [0.48235294, 0.27058824, 0.14117647]],
#
#        [[0.80784314, 0.80392157, 0.76470588],
#         [0.81960784, 0.81960784, 0.79215686],
#         [0.83529412, 0.84313725, 0.81960784],
#         ...,
#         [0.48627451, 0.2745098 , 0.14509804],
#         [0.51372549, 0.30196078, 0.16470588],
#         [0.51372549, 0.30588235, 0.16078431]],
#
#        ...,
#
#        [[0.49803922, 0.42352941, 0.38039216],
# ...

# %%
X_train[0]
# Out:
# array([[[209, 210, 203],
#         [213, 214, 209],
#         [218, 219, 215],
#         ...,
#         [127,  74,  39],
#         [122,  68,  35],
#         [116,  63,  32]],
#
#        [[210, 210, 202],
#         [213, 214, 207],
#         [218, 220, 214],
#         ...,
#         [124,  70,  35],
#         [121,  67,  33],
#         [123,  69,  36]],
#
#        [[206, 205, 195],
#         [209, 209, 202],
#         [213, 215, 209],
#         ...,
#         [124,  70,  37],
#         [131,  77,  42],
#         [131,  78,  41]],
#
#        ...,
#
#        [[127, 108,  97],
#         [138, 122, 110],
#         [141, 127, 118],
#         ...,
#         [158, 149, 134],
#         [161, 156, 151],
#         [136, 137, 148]],
#
#        [[145, 130, 119],
#         [148, 135, 128],
#         [136, 127, 128],
#         ...,
#         [175, 174, 172],
#         [160, 161, 170],
#         [143, 148, 164]],
#
#        [[138, 128, 123],
#         [140, 132, 136],
#         [136, 131, 140],
# ...

# %% [markdown]
# **Building the Neural network**

# %%
import tensorflow as tf
from tensorflow import keras

# %%
umm_of_classes = 10

# setting up the layers of Neural Network

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32,32,3)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(umm_of_classes, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# compile the neural network

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train_scaled, Y_train, validation_split=0.1, epochs=10)
# Out:
# Epoch 1/10
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.2855 - loss: 1.9428 - val_accuracy: 0.3338 - val_loss: 1.8189
# Epoch 2/10
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3408 - loss: 1.8233 - val_accuracy: 0.3343 - val_loss: 1.8347
# Epoch 3/10
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3529 - loss: 1.7844 - val_accuracy: 0.3582 - val_loss: 1.7539
# Epoch 4/10
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3645 - loss: 1.7588 - val_accuracy: 0.3747 - val_loss: 1.7223
# Epoch 5/10
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3701 - loss: 1.7393 - val_accuracy: 0.3525 - val_loss: 1.7638
# Epoch 6/10
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3782 - loss: 1.7254 - val_accuracy: 0.3767 - val_loss: 1.7374
# Epoch 7/10
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3809 - loss: 1.7120 - val_accuracy: 0.3823 - val_loss: 1.6973
# Epoch 8/10
# ...

# %% [markdown]
# ResNet50

# %%
from tensorflow.keras import Sequential, models , layers
from tensorflow.keras.layers import Dense , Flatten, Dropout , BatchNormalization
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras import optimizers

# %%
convolutional_base = ResNet50(weights='imagenet', include_top=False, input_shape=(256,256,3))
convolutional_base.summary()
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "resnet50"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 262, 262,  │          0 │ input_layer_4[0]… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 128, 128,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ...

# %%
model = models.Sequential()
model.add(layers.UpSampling2D((2,2)))
model.add(layers.UpSampling2D((2,2)))
model.add(layers.UpSampling2D((2,2)))
model.add(convolutional_base)
model.add(layers.Flatten())
model.add(layers.BatchNormalization())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.BatchNormalization())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.BatchNormalization())
model.add(layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer=optimizers.RMSprop(learning_rate=2e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['acc'])

# %%
history = model.fit(X_train_scaled, Y_train, validation_split=0.1, epochs=10)
# Out:
# Epoch 1/10
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 411s 365ms/step - acc: 0.4609 - loss: 1.6324 - val_acc: 0.7717 - val_loss: 0.8120
# Epoch 2/10
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 407s 362ms/step - acc: 0.7122 - loss: 0.9647 - val_acc: 0.8935 - val_loss: 0.4410
# Epoch 3/10
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 406s 361ms/step - acc: 0.8194 - loss: 0.7009 - val_acc: 0.9210 - val_loss: 0.3258
# Epoch 4/10
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 406s 361ms/step - acc: 0.8766 - loss: 0.5393 - val_acc: 0.9337 - val_loss: 0.2758
# Epoch 5/10
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 406s 361ms/step - acc: 0.9138 - loss: 0.4228 - val_acc: 0.9312 - val_loss: 0.2492
# Epoch 6/10
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 405s 360ms/step - acc: 0.9398 - loss: 0.3332 - val_acc: 0.9355 - val_loss: 0.2275
# Epoch 7/10
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 407s 361ms/step - acc: 0.9543 - loss: 0.2724 - val_acc: 0.9358 - val_loss: 0.2318
# Epoch 8/10
# ...

# %%
loss, accuracy = model.evaluate(X_test_scaled, Y_test)
print('Test Accuracy =', accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 115ms/step - acc: 0.9367 - loss: 0.2374
# Test Accuracy = 0.9366999864578247

# %%
h = history

# plot the loss value
plt.plot(h.history['loss'], label='train loss')
plt.plot(h.history['val_loss'], label='validation loss')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# plot the accuracy value
plt.plot(h.history['acc'], label='train accuracy')
plt.plot(h.history['val_acc'], label='validation accuracy')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Make predictions on the test set
Y_pred_probs = model.predict(X_test_scaled)
Y_pred = np.argmax(Y_pred_probs, axis=1)

# Generate Confusion Matrix
conf_mat = confusion_matrix(Y_test, Y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Generate Classification Report
# Need class names for a more readable report
class_names = list(labels_dictionary.keys()) # Assuming labels_dictionary is available from previous cells
print('\nClassification Report:')
print(classification_report(Y_test, Y_pred, target_names=class_names))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 129ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#     airplane       0.95      0.94      0.94      1029
#   automobile       0.97      0.96      0.97       996
#         bird       0.95      0.91      0.93      1031
#          cat       0.84      0.91      0.87       982
#         deer       0.91      0.95      0.93      1008
#          dog       0.92      0.86      0.89       998
#         frog       0.97      0.95      0.96       994
#        horse       0.95      0.94      0.95       998
#         ship       0.97      0.97      0.97       989
#        truck       0.95      0.97      0.96       975
#
#     accuracy                           0.94     10000
#    macro avg       0.94      0.94      0.94     10000
# weighted avg       0.94      0.94      0.94     10000
